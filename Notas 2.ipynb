# %% [markdown]
# <h1>Clase 2 Agenda </h1>
#
# 1. Listas
# 2. Diccionarios
# 3. Pandas

# %% [markdown]
# <h1> Listas</h1>
#
# <h3>¿que es una lista? </h3>
#
# una lista es una colección de elementos que tienen un orden particular.
#
# ejemplos
#
# --> una lista con las letras del alphabeto
# -->digitos del 1 al 9
# --> O los nombres de todas las personas de tu familia
#
# Una lista se construye utlizando los []
#  y aca elemento de la lista se separa por medio de ,
#
#  Ejemplo nombres = ['Pedro','Juan']
#
# <h3> Como acceder a un item </h3>
#
# - tienes que expecificar el indice del item que estas biscando por medio de un []
#
# por ejemplo impriman el nombre de su papa
#
# print(names[0])
#
# <h3> Modificar elementos en una lista </h3>
#
# Accedemos el valor como lo vimos anterioremente y le asiganmos otro valor
#
# names[0]="Paco"
#
#
# <h3> Agregar un elemento al final de la lista </h3>
#
# utilizando la función de append
# names.append("Paco")
#
# <h3> Agregar un elemento  de la lista en una posición</h3>
#
# names.insert(0,"Paco")
#
# <h3> Eliminar un elemento  de la lista en una posición conocida</h3>
#
# del names[1]
#
# <h3> Eliminar el ultimo elemento  de una lista</h3>
#
# -pero todavia quieres utilizar el valor
#
# valor_eliminado = names.pop()
# print(names)
# print(valor_eliminado)
#
# valor_eliminado = names.pop(3)
#
# <h3> Eliminar un elemento de una lista utilizando el valor</h3>
#
# - Utilizando la formula de remove
#
# names.remove('Guaro')
# print(names)
#
# <h3> Ordenar los elementos de una lista</h3>
#
# names.sort() a->z
# names.sort(reverse=True)
# sorted(names) --> para ordenar la lista de manera temporal
#
#
# <h3> Ordenar los elementos de una lista de atras para a delante</h3>
# - Utilizando la función .reverse()
#
# names.reverse()
#
# <h3> Encontrar el numero de elemnetos en una lista</h3>
# len(names)
#
# <h3> Otros elementos a considerar</h3>
#
# para seleccionar el ultimo elemento de una lista siempre es el [-1]
#
#
# <h3> For loop</h3>
# for cat in cats:
#     print(cat)
#
# generar

# %% [markdown]
# <h1> Sección de Pandas </h1>
#
# Pandas es un paquete de Python diseñado para la manipulación de datos y tambien para la visualización de datos. Esta construida sobre otras dos bibliotecas muy importantes de python las cuales son Numpy y Matplotlib
#
# Data Frames --> El concepto principal de Pandas
#
# Pandas esta diseñado para trabajar con tablas o datos en ingles conocidos como rectangular data en donde cada fila es un individuo y cada columna es el atributo de ese individuo. y esto es lo que se le conoce en pandas como Data Frames.
#
# lo primero que quieres hacer cuando adquieres un data frame es explorar los contenidos que tenemos.

# %% [markdown]
# # import pandas as pd
# import numpy as np
# import datetime as dt
# import yfinance as yf
# import pandas_datareader.data as web
#
# #Crear variables
# Año = 2006
# Mes = 11
# Dia = 15
# Freq = "5d" #1D 352,5D,1WK,1MO,3MO
# acciones = ["APPL","TSLA"]
# inicio = dt.datetime(Año,Mes,Dia)
# final = dt.datetime.now()
#
#
# #Recopilar la información accionaria
# datos = web.DataReader('GE', 'yahoo', start='2019-09-10', end='2019-10-09')
# datos.head()
