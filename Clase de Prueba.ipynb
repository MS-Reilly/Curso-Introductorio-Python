# %%
pip --version
# Out:
# pip 20.2.4 from /Users/reilly/opt/anaconda3/lib/python3.8/site-packages/pip (python 3.8)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --pre statsmodels --upgrade
# Out:
# ...
#      |████████████████████████████████| 9.5 MB 6.5 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 233 kB 3.7 MB/s eta 0:00:01
# ...
#   Attempting uninstall: patsy
#     Found existing installation: patsy 0.5.1
#     Uninstalling patsy-0.5.1:
#       Successfully uninstalled patsy-0.5.1
#   Attempting uninstall: statsmodels
#     Found existing installation: statsmodels 0.12.0
#     Uninstalling statsmodels-0.12.0:
#       Successfully uninstalled statsmodels-0.12.0
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

df = pd.read_csv("Datos PIB.csv")
print(df.head())
# Out:
#    Tiempo         PIB
# 0       1  10,063,400
# 1       2  10,091,898
# 2       3  10,201,269
# 3       4  10,328,667
# 4       5  10,433,519

# %%
# %matplotlib inline
plt.xlabel("Tiempo")
plt.ylabel("PIB")
plt.scatter(df.Tiempo,df.PIB,color="red",marker="+")
