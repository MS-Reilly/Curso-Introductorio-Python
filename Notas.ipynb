# %% [markdown]
# <h1>Jupiter Notebook</h1>
# <ol>
#     <li>Que es?</li>
#      <li>Formas de abrirlo (No cerrar la terminal a que es un servidor)</li>
#     <li>Cambiar File name</li>
#     <li>Help --> Tour</li>
#     <li>Hello world</li>
#     <li>3 tipos de Run</li>
#     <li>numeros de la izqiuerda es el orden de ejecución</li>
#     <li>Markdown</li>
#     <li>Magic commands
#         <ul>
#             <li>%ls Magic</li>
#             <li>%Matplotlib inline (Mostrar codigo de abajo)</li>
#             <li>%ls HTML</li>
#             <li>%ls timeit</li>
#         </ul>
#     </li>
#     <li>Pandas</li>
#     <li>Exportar como HTML</li>
#
#
# </ol>

# %%
import numpy as np
import matplotlib.pyplot as plt

# define a list of markevery cases to plot
cases = [None,
         8,
         (30, 8),
         [16, 24, 30], [0, -1],
         slice(100, 200, 3),
         0.1, 0.3, 1.5,
         (0.0, 0.1), (0.45, 0.1)]

# define the figure size and grid layout properties
figsize = (10, 8)
cols = 3
rows = len(cases) // cols + 1
# define the data for cartesian plots
delta = 0.11
x = np.linspace(0, 10 - 2 * delta, 200) + delta
y = np.sin(x) + 1.0 + delta


def trim_axs(axs, N):
    """
    Reduce *axs* to *N* Axes. All further Axes are removed from the figure.
    """
    axs = axs.flat
    for ax in axs[N:]:
        ax.remove()
    return axs[:N]

axs = plt.figure(figsize=figsize, constrained_layout=True).subplots(rows, cols)
axs = trim_axs(axs, len(cases))
for ax, case in zip(axs, cases):
    ax.set_title('mary=%s' % str(case))
    ax.plot(x, y, 'o', ls='-', ms=4, markevery=case)

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame(np.random.randn(100,2))

print (df)
# Out:
#            0         1
# 0  -0.514300 -0.267443
# 1   0.177390 -1.412756
# 2  -0.912715  0.462743
# 3  -0.275760 -0.685551
# 4  -0.611597  0.074635
# ..       ...       ...
# 95 -0.387270 -1.560679
# 96 -1.099355  0.319924
# 97  0.519215  1.380492
# 98 -0.677743  1.783795
# 99  2.013180  1.469719
#
# [100 rows x 2 columns]

# %% [markdown]
# <h1>Variables:</h1>
#
# - EL nombre de las variables puede contener letras, numeros y guiones bajos
# - Pueden empezar con un guion bajo o con una letra pero no con un numero
#     (mostrar ejemplo de que pasa si hacen eso con un numero)
# - Los espacios no estan permitidos a la hora de nombrar una variable
# - evitar usar nombres de funciones que esten precargadas en python
# - el nombre de las variables debe ser corto pero descriptivo
#
# Las variables son como etiquetas a las cuales le puedes asignar valores
#
# Ejercicio 1
#
# Asignar a la variable "edad" su edad en años e imprimir el valor

# %% [markdown]
# <h1>Strings</h1>
#
# - un string se define como un conjunto de caracteres
# - un string en python se caracteriza por ser todo lo que este adentro de comillas dobles o simples
#  (print ejemplo esto es un string) esto tambien
# - por que hay dos formas de usar strings por si se presentan casos asi "Programando en 'python'"
# - Funciones de los Strings
#     - """ para multiples lineas"""
#     - str.title() para poner mayusculas y minusculas
#     - str.upper() todo en mayusculas
#     - str.lower() todo en minusculas
#     - Agregar un tab a la palabra \t
#     - Agregar una nueva linea \n
#     - eliminar espacios en blanco de la palabra str.rstrip(),str.lstrip(),str.strip()
#     - remplazar palabras o texto con la función str.replace(palabra vieja, palabra nueva)
#     - numero de caracteres en el texto len()
#     - buscar letras por indices
#     - verificar que una palabra este en el string

# %% [markdown]
# <h1> Integers and Floats</h1>
#
# - +
# - -
# - *
# - /
# - ** exponente
# - %
